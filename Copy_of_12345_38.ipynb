# %% [markdown]
# # Gesture Recognition
# In this group project, you are going to build a 3D Conv model that will be able to predict the 5 gestures correctly. Please import the following libraries to get started.

# %%
import numpy as np
import os
#from scipy.misc import imread, imresize
import imageio.v2 as imageio
from imageio.v2 import imread
from skimage.transform import resize
import datetime
import os
from PIL import Image, ImageFilter, ImageEnhance
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# We set the random seed so that the results don't vary drastically.

# %%
#import os
#os.environ['PYTHONHASHSEED']="30"
#from collections.abc import Iterable
#from collections import Iterable
np.random.seed(30)
import random as rn
rn.seed(30)
import tensorflow as tf
tf.random.set_seed(30)
from keras import backend as K

# %% [markdown]
# In this block, you read the folder names for training and validation. You also set the `batch_size` here. Note that you set the batch size in such a way that you are able to use the GPU in full capacity. You keep increasing the batch size until the machine throws an error.

# %%
# train and validatiaon data creator with ablation
# when ablation is 10, then 10 folders for each label will be selected.
def get_data(path, ablation=None):
    train_doc = np.random.permutation(open(path+'train.csv').readlines())
    val_doc = np.random.permutation(open(path+'val.csv').readlines())
    counts = np.zeros(5) # count for loading folders for 5 classes
    train_data = []
    val_data = []
    # when ablation is None pass full training and val data
    if ablation is not None:
        # iterating train doc
        for doc in train_doc:
            lable = int(doc.strip().split(';')[2])
            if counts[lable] < ablation:
                train_data.append(doc)
                counts[lable] += 1
        counts = np.zeros(5)
        # iterating val doc
        for doc in val_doc:
            lable = int(doc.strip().split(';')[2])
            if counts[lable] < ablation:
                val_data.append(doc)
                counts[lable] += 1
    else:
        train_data, val_data = train_doc, val_doc
    return train_data, val_data

# %%
from google.colab import drive
drive.mount('/content/gdrive')
root_path = 'gdrive/My Drive/Project_data/'
# Out:
# Mounted at /content/gdrive

# %%
train_doc = np.random.permutation(open(root_path + 'train.csv').readlines())
val_doc = np.random.permutation(open(root_path + 'val.csv').readlines())

# %%
#train_doc, val_doc = get_data('Project_data/', ablation=None)
#train_doc, val_doc = get_data(r'C:/Sayed/gesture/Project_data/', ablation=None)

batch_size = 32 # experiment with the batch size
enable_augmentation = False # augmentation of Data
# sequence ids
# selecting alternate frames from 7 to 26.
seq_idx = range(7,26,2)
# image dimensions
dim_x, dim_y = 120, 120

# %% [markdown]
# ## Generator
# This is one of the most important part of the code. The overall structure of the generator has been given. In the generator, you are going to preprocess the images as you have images of 2 different dimensions as well as create a batch of video frames. You have to experiment with `img_idx`, `y`,`z` and normalization such that you get high accuracy.

# %%
# generator with augmentation for train data
def generator(source_path, folder_list, batch_size, is_train = False, augmention = False, debug=False):
    # print('\nSource path = ', source_path, '; batch size =', batch_size)
    img_idx = seq_idx #create a list of image numbers you want to use for a particular video
    x = len(img_idx)
    y, z = dim_x, dim_y
    while True:
        # doubling the data for augmentation
        if is_train and augmention:
            t = np.concatenate((np.random.permutation(folder_list), np.random.permutation(folder_list)))
        else:
            t = np.random.permutation(folder_list)

        if (len(t)%batch_size) == 0:
            num_batches = int(len(t)/batch_size)
        else:
            num_batches = len(t)//batch_size + 1

        for batch in range(num_batches): # we iterate over the number of batches
            batch_data = np.zeros((batch_size,x,y,z,3)) # x is the number of images you use for each video, (y,z) is the final size of the input images and 3 is the number of channels RGB
            batch_labels = np.zeros((batch_size,5)) # batch_labels is the one hot representation of the output
            for folder in range(batch_size): # iterate over the batch_size
                if debug:
                    plt.figure(figsize=(20,5))
                #handling remaining datapoints
                folder_idx = folder + (batch*batch_size)
                if folder_idx >= len(t):
                    break
                folder_str = t[folder_idx]
                imgs = os.listdir(source_path+'/'+ folder_str.split(';')[0]) # read all the images in the folder
                # randomly enabling augmentation and augmentation type
                aug_type = None
                if is_train and augmention and rn.randint(0,1) == 1:
                    aug_type = rn.randint(0, 4) #randomly selecting augmentation type
                for idx,item in enumerate(img_idx): #  Iterate iver the frames/images of a folder to read them in
                    image = imread(source_path+'/'+ folder_str.strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)

                    # plotting original images for debugging purpose only
                    if debug:
                        plt.subplot(2, x, idx+1)
                        plt.imshow(image.astype('uint8'))

                    #crop the images and resize them. Note that the images are of 2 different shape .
                    #and the conv3D will throw error if the inputs in a batch have different shapes
                    # making the rectangle images into square by cropping sides
                    # so the aspect ration can be mantained while resizing.
                    if image.shape[1] > image.shape[0]:
                        diff_px = image.shape[1] - image.shape[0]
                        crop_start = diff_px//2
                        crop_end = crop_start + image.shape[0]
                        image = image[:, crop_start:crop_end]
                    elif image.shape[0] > image.shape[1]:
                        diff_px = image.shape[0] - image.shape[1]
                        crop_start = diff_px//2
                        crop_end = crop_start + image.shape[1]
                        image = image[:, crop_start:crop_end]

                    resized_im = resize(image, (y, z))
                    #resized_im = resize(image, size=(y,z))

                    if aug_type is not None:
                        if aug_type == 0: # edge Enhancement
                            resized_im = np.array(Image.fromarray(resized_im, 'RGB').filter(ImageFilter.EDGE_ENHANCE))
                        elif aug_type == 1: # adding gaussian blur
                            resized_im = np.array(Image.fromarray(resized_im, 'RGB').filter(ImageFilter.GaussianBlur(1)))
                        elif aug_type == 2: # enchancing image detailing
                            resized_im = np.array(Image.fromarray(resized_im, 'RGB').filter(ImageFilter.DETAIL))
                        elif aug_type == 3: # sharpening image
                            resized_im = np.array(Image.fromarray(resized_im, 'RGB').filter(ImageFilter.SHARPEN))
                        elif aug_type == 4: # Brightness enhancement
                            resized_im = np.array(ImageEnhance.Brightness((Image.fromarray(resized_im, 'RGB'))).enhance(1.5))
                    # plotting rezised images for debugging purpose only
                    if debug:
                        plt.subplot(2, x, idx+x+1)
                        plt.imshow(resized_im)

                    batch_data[folder,idx,:,:,0] = resized_im[:,:,0]/255 #normalise and feed in the image
                    batch_data[folder,idx,:,:,1] = resized_im[:,:,1]/255 #normalise and feed in the image
                    batch_data[folder,idx,:,:,2] = resized_im[:,:,2]/255 #normalise and feed in the image

                batch_labels[folder, int(folder_str.strip().split(';')[2])] = 1
            yield batch_data, batch_labels #you yield the batch_data and the batch_labels, remember what does yield do

# %% [markdown]
# Note here that a video is represented above in the generator as (number of images, height, width, number of channels). Take this into consideration while creating the model architecture.

# %%
curr_dt_time = datetime.datetime.now()
train_path = 'gdrive/My Drive/Project_data/train' #'/notebooks/storage/Final_data/Collated_training/train'
val_path =  'gdrive/My Drive/Project_data/val' #'/notebooks/storage/Final_data/Collated_training/val'

#multiply number train seq by 2 when using augmentation
multiplier = 1
if enable_augmentation:
    multiplier = 2
num_train_sequences = len(train_doc)*multiplier
print('# training sequences =', num_train_sequences)

num_val_sequences = len(val_doc)
print('# validation sequences =', num_val_sequences)

num_epochs = 38 # choose the number of epochs
print ('# epochs =', num_epochs)
# Out:
# # training sequences = 663
# # validation sequences = 100
# # epochs = 38

# %%
# testing generative
test_gen = generator(train_path, train_doc, 1, is_train = True, augmention = True, debug = True)
d = next(test_gen)[0]

# %% [markdown]
# ## Model
# Here you make the model using different functionalities that Keras provides. Remember to use `Conv3D` and `MaxPooling3D` and not `Conv2D` and `Maxpooling2D` for a 3D convolution model. You would want to use `TimeDistributed` while building a Conv2D + RNN model. Also remember that the last layer is the softmax. Design the network in such a way that the model is able to give good accuracy on the least number of parameters so that it can fit in the memory of the webcam.

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, GRU, Flatten, TimeDistributed, Bidirectional, BatchNormalization, Activation, Dropout, GlobalAveragePooling2D, GlobalAveragePooling3D, ConvLSTM2D
from tensorflow.keras.layers import Conv2D, Conv3D, MaxPooling2D, MaxPooling3D
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau

# input shape for the st layer
input_shape = (len(seq_idx), dim_x, dim_y, 3)
tf.random.set_seed(30)  # setting random seed with TensorFlow

# %% [markdown]
# ### Experiment -  1
# **Conv3D**

# %%
 # tested with EPoch 25 and accuracy is 90 for train and 60 for validation
 #model = Sequential()

 #model.add(Conv3D(32, kernel_size=3, activation='relu', input_shape=input_shape))
 #model.add(Conv3D(64, kernel_size=3, activation='relu'))
 #model.add(MaxPooling3D(pool_size=(2, 2, 2)))
 #model.add(BatchNormalization())

 #model.add(Conv3D(128, kernel_size=3, activation='relu'))
 #model.add(MaxPooling3D(pool_size=(1, 2, 2)))
 #model.add(BatchNormalization())

 #model.add(Conv3D(256, kernel_size=(1, 3, 3), activation='relu'))
 #model.add(MaxPooling3D(pool_size=(1, 2, 2)))
 #model.add(BatchNormalization())

 #model.add(Conv3D(512, kernel_size=(1, 3, 3), activation='relu'))
 #model.add(Conv3D(512, kernel_size=(1, 3, 3), activation='relu'))
 #model.add(MaxPooling3D(pool_size=(1, 2, 2)))
 #model.add(BatchNormalization())

 #model.add(Flatten())
 #model.add(Dense(512, activation='relu'))
 #model.add(BatchNormalization())
 #model.add(Dense(5, activation='softmax'))

# %% [markdown]
# ### Experiment - 2
# **Conv3D**

# %%
 #model = Sequential()

 #model.add(Conv3D(32, kernel_size=3, activation='relu', input_shape=input_shape))
 #model.add(Conv3D(64, kernel_size=3, activation='relu'))
 #model.add(MaxPooling3D(pool_size=(2, 2, 2)))
 #model.add(BatchNormalization())
 #model.add(Dropout(0.2))
 #model.add(Dropout(0.5))

 #model.add(Conv3D(128, kernel_size=3, activation='relu'))
 #model.add(MaxPooling3D(pool_size=(1, 2, 2)))
 #model.add(BatchNormalization())
 #model.add(Dropout(0.2))
 #model.add(Dropout(0.5))

 #model.add(Conv3D(256, kernel_size=(1, 3, 3), activation='relu'))
 #model.add(MaxPooling3D(pool_size=(1, 2, 2)))
 #model.add(BatchNormalization())
 #model.add(Dropout(0.2))
 #model.add(Dropout(0.5))

 #model.add(Conv3D(512, kernel_size=(1, 3, 3), activation='relu'))
 #model.add(Conv3D(512, kernel_size=(1, 3, 3), activation='relu'))
 #model.add(MaxPooling3D(pool_size=(1, 2, 2)))
 #model.add(BatchNormalization())
 #model.add(Dropout(0.2))
 #model.add(Dropout(0.5))

 #model.add(Flatten())
 #model.add(Dense(512, activation='relu'))
 #model.add(BatchNormalization())
 #model.add(Dense(5, activation='softmax'))

# %% [markdown]
# # with Epoch 50 its deviating so Converged the Model at Epoch 38,

# %%
model = Sequential()
model.add(TimeDistributed(
    Conv2D(8, (3,3), activation='relu'), input_shape=input_shape)
)
model.add(BatchNormalization())
model.add(TimeDistributed(
    Conv2D(16, (3,3), activation='relu'))
)
model.add(BatchNormalization())
model.add(
    ConvLSTM2D(8, kernel_size = 3, return_sequences=False)
)
model.add(BatchNormalization())
model.add(TimeDistributed(
    Dense(64, activation='relu'))
)
model.add(BatchNormalization())
model.add(GlobalAveragePooling2D())
model.add(Dense(64, activation='relu'))
model.add(Dense(5, activation='softmax'))

# %% [markdown]
# Now that you have written the model, the next step is to `compile` the model. When you print the `summary` of the model, you'll see the total number of parameters you have to train.

# %%
optimizer = tf.keras.optimizers.Adam(lr=0.01)

# Compile your model
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['categorical_accuracy'])

# Print model summary
print(model.summary())
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time_distributed (TimeDist  (None, 10, 118, 118, 8)   224
#  ributed)
#
#  batch_normalization (Batch  (None, 10, 118, 118, 8)   32
#  Normalization)
#
#  time_distributed_1 (TimeDi  (None, 10, 116, 116, 16   1168
#  stributed)                  )
#
#  batch_normalization_1 (Bat  (None, 10, 116, 116, 16   64
#  chNormalization)            )
#
#  conv_lstm2d (ConvLSTM2D)    (None, 114, 114, 8)       6944
#
#  batch_normalization_2 (Bat  (None, 114, 114, 8)       32
#  chNormalization)
#
#  time_distributed_2 (TimeDi  (None, 114, 114, 64)      576
#  stributed)
#
#  batch_normalization_3 (Bat  (None, 114, 114, 64)      256
#  chNormalization)
#
#  global_average_pooling2d (  (None, 64)                0
#  GlobalAveragePooling2D)
#
#  dense_1 (Dense)             (None, 64)                4160
#
#  dense_2 (Dense)             (None, 5)                 325
#
# =================================================================
# Total params: 13781 (53.83 KB)
# Trainable params: 13589 (53.08 KB)
# Non-trainable params: 192 (768.00 Byte)
# _________________________________________________________________
# None

# %% [markdown]
# Let us create the `train_generator` and the `val_generator` which will be used in `.fit_generator`.

# %%
train_generator = generator(train_path, train_doc, batch_size, is_train = True, augmention = enable_augmentation)
val_generator = generator(val_path, val_doc, batch_size)

# %%
model_name = 'model_init_exp_16' + '_' + str(curr_dt_time).replace(' ','').replace(':','_') + '/'

if not os.path.exists(model_name):
    os.mkdir(model_name)

filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.h5'

checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=False, save_weights_only=False, mode='auto', period=1)

LR = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=0.001, verbose=1) # write the REducelronplateau code here

callbacks_list = [checkpoint, LR]
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %% [markdown]
# The `steps_per_epoch` and `validation_steps` are used by `fit_generator` to decide the number of next() calls it need to make.

# %%
if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1

# %% [markdown]
# Let us now fit the model. This will start training the model and with the help of the checkpoints, you'll be able to save the model at the end of each epoch.

# %%
history = model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1,
                        callbacks=callbacks_list, validation_data=val_generator,
                        validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Epoch 1/38
# 21/21 [==============================] - ETA: 0s - loss: 1.5001 - categorical_accuracy: 0.3259
# Epoch 1: saving model to model_init_exp_16_2024-04-2403_19_46.805264/model-00001-1.50007-0.32589-1.25134-0.18750.h5
# 21/21 [==============================] - 2701s 134s/step - loss: 1.5001 - categorical_accuracy: 0.3259 - val_loss: 1.2513 - val_categorical_accuracy: 0.1875 - lr: 0.0010
# Epoch 2/38
# 21/21 [==============================] - ETA: 0s - loss: 1.3147 - categorical_accuracy: 0.4583
# Epoch 2: saving model to model_init_exp_16_2024-04-2403_19_46.805264/model-00002-1.31475-0.45833-1.23005-0.22656.h5
# 21/21 [==============================] - 608s 29s/step - loss: 1.3147 - categorical_accuracy: 0.4583 - val_loss: 1.2300 - val_categorical_accuracy: 0.2266 - lr: 0.0010
# Epoch 3/38
# 21/21 [==============================] - ETA: 0s - loss: 1.1477 - categorical_accuracy: 0.5312
# Epoch 3: saving model to model_init_exp_16_2024-04-2403_19_46.805264/model-00003-1.14769-0.53125-1.23999-0.17188.h5
# 21/21 [==============================] - 595s 29s/step - loss: 1.1477 - categorical_accuracy: 0.5312 - val_loss: 1.2400 - val_categorical_accuracy: 0.1719 - lr: 0.0010
# Epoch 4/38
# 21/21 [==============================] - ETA: 0s - loss: 1.0592 - categorical_accuracy: 0.5640
# Epoch 4: saving model to model_init_exp_16_2024-04-2403_19_46.805264/model-00004-1.05919-0.56399-1.22098-0.21875.h5
# 21/21 [==============================] - 610s 29s/step - loss: 1.0592 - categorical_accuracy: 0.5640 - val_loss: 1.2210 - val_categorical_accuracy: 0.2188 - lr: 0.0010
# Epoch 5/38
# 21/21 [==============================] - ETA: 0s - loss: 1.0425 - categorical_accuracy: 0.5699
# Epoch 5: saving model to model_init_exp_16_2024-04-2403_19_46.805264/model-00005-1.04249-0.56994-1.36573-0.16406.h5
# 21/21 [==============================] - 606s 29s/step - loss: 1.0425 - categorical_accuracy: 0.5699 - val_loss: 1.3657 - val_categorical_accuracy: 0.1641 - lr: 0.0010
# Epoch 6/38
# 21/21 [==============================] - ETA: 0s - loss: 0.9469 - categorical_accuracy: 0.6116
# Epoch 6: saving model to model_init_exp_16_2024-04-2403_19_46.805264/model-00006-0.94694-0.61161-1.27735-0.17969.h5
# 21/21 [==============================] - 591s 28s/step - loss: 0.9469 - categorical_accuracy: 0.6116 - val_loss: 1.2773 - val_categorical_accuracy: 0.1797 - lr: 0.0010
# Epoch 7/38
# 21/21 [==============================] - ETA: 0s - loss: 0.8772 - categorical_accuracy: 0.6369
# Epoch 7: saving model to model_init_exp_16_2024-04-2403_19_46.805264/model-00007-0.87721-0.63690-1.42851-0.15625.h5
# 21/21 [==============================] - 596s 28s/step - loss: 0.8772 - categorical_accuracy: 0.6369 - val_loss: 1.4285 - val_categorical_accuracy: 0.1562 - lr: 0.0010
# Epoch 8/38
# 21/21 [==============================] - ETA: 0s - loss: 0.8147 - categorical_accuracy: 0.6830
# Epoch 8: saving model to model_init_exp_16_2024-04-2403_19_46.805264/model-00008-0.81469-0.68304-1.42936-0.16406.h5
# 21/21 [==============================] - 594s 28s/step - loss: 0.8147 - categorical_accuracy: 0.6830 - val_loss: 1.4294 - val_categorical_accuracy: 0.1641 - lr: 0.0010
# Epoch 9/38
# 21/21 [==============================] - ETA: 0s - loss: 0.7832 - categorical_accuracy: 0.6890
# Epoch 9: saving model to model_init_exp_16_2024-04-2403_19_46.805264/model-00009-0.78317-0.68899-1.73368-0.17188.h5
# 21/21 [==============================] - 586s 28s/step - loss: 0.7832 - categorical_accuracy: 0.6890 - val_loss: 1.7337 - val_categorical_accuracy: 0.1719 - lr: 0.0010
# Epoch 10/38
# 21/21 [==============================] - ETA: 0s - loss: 0.7368 - categorical_accuracy: 0.7009
# Epoch 10: saving model to model_init_exp_16_2024-04-2403_19_46.805264/model-00010-0.73680-0.70089-1.88107-0.14844.h5
# 21/21 [==============================] - 622s 30s/step - loss: 0.7368 - categorical_accuracy: 0.7009 - val_loss: 1.8811 - val_categorical_accuracy: 0.1484 - lr: 0.0010
# Epoch 11/38
# 21/21 [==============================] - ETA: 0s - loss: 0.7198 - categorical_accuracy: 0.6964
# Epoch 11: saving model to model_init_exp_16_2024-04-2403_19_46.805264/model-00011-0.71978-0.69643-1.61210-0.15625.h5
# 21/21 [==============================] - 616s 29s/step - loss: 0.7198 - categorical_accuracy: 0.6964 - val_loss: 1.6121 - val_categorical_accuracy: 0.1562 - lr: 0.0010
# Epoch 12/38
# 21/21 [==============================] - ETA: 0s - loss: 0.7337 - categorical_accuracy: 0.7039
# Epoch 12: saving model to model_init_exp_16_2024-04-2403_19_46.805264/model-00012-0.73366-0.70387-1.75501-0.14844.h5
# 21/21 [==============================] - 598s 29s/step - loss: 0.7337 - categorical_accuracy: 0.7039 - val_loss: 1.7550 - val_categorical_accuracy: 0.1484 - lr: 0.0010
# Epoch 13/38
# 21/21 [==============================] - ETA: 0s - loss: 0.7062 - categorical_accuracy: 0.7054
# Epoch 13: saving model to model_init_exp_16_2024-04-2403_19_46.805264/model-00013-0.70619-0.70536-2.03094-0.14062.h5
# 21/21 [==============================] - 594s 28s/step - loss: 0.7062 - categorical_accuracy: 0.7054 - val_loss: 2.0309 - val_categorical_accuracy: 0.1406 - lr: 0.0010
# Epoch 14/38
# 21/21 [==============================] - ETA: 0s - loss: 0.6823 - categorical_accuracy: 0.7188
# Epoch 14: saving model to model_init_exp_16_2024-04-2403_19_46.805264/model-00014-0.68232-0.71875-1.99643-0.17969.h5
# 21/21 [==============================] - 601s 29s/step - loss: 0.6823 - categorical_accuracy: 0.7188 - val_loss: 1.9964 - val_categorical_accuracy: 0.1797 - lr: 0.0010
# Epoch 15/38
# 21/21 [==============================] - ETA: 0s - loss: 0.6357 - categorical_accuracy: 0.7232
# Epoch 15: saving model to model_init_exp_16_2024-04-2403_19_46.805264/model-00015-0.63566-0.72321-2.22682-0.18750.h5
# 21/21 [==============================] - 594s 28s/step - loss: 0.6357 - categorical_accuracy: 0.7232 - val_loss: 2.2268 - val_categorical_accuracy: 0.1875 - lr: 0.0010
# Epoch 16/38
# 21/21 [==============================] - ETA: 0s - loss: 0.6100 - categorical_accuracy: 0.7515
# Epoch 16: saving model to model_init_exp_16_2024-04-2403_19_46.805264/model-00016-0.60998-0.75149-2.41925-0.17969.h5
# 21/21 [==============================] - 595s 28s/step - loss: 0.6100 - categorical_accuracy: 0.7515 - val_loss: 2.4193 - val_categorical_accuracy: 0.1797 - lr: 0.0010
# Epoch 17/38
# 21/21 [==============================] - ETA: 0s - loss: 0.5952 - categorical_accuracy: 0.7693
# Epoch 17: saving model to model_init_exp_16_2024-04-2403_19_46.805264/model-00017-0.59525-0.76935-2.39129-0.14844.h5
# 21/21 [==============================] - 591s 28s/step - loss: 0.5952 - categorical_accuracy: 0.7693 - val_loss: 2.3913 - val_categorical_accuracy: 0.1484 - lr: 0.0010
# Epoch 18/38
# 21/21 [==============================] - ETA: 0s - loss: 0.8355 - categorical_accuracy: 0.6518
# Epoch 18: saving model to model_init_exp_16_2024-04-2403_19_46.805264/model-00018-0.83554-0.65179-2.38024-0.19531.h5
# 21/21 [==============================] - 597s 28s/step - loss: 0.8355 - categorical_accuracy: 0.6518 - val_loss: 2.3802 - val_categorical_accuracy: 0.1953 - lr: 0.0010
# Epoch 19/38
# 21/21 [==============================] - ETA: 0s - loss: 0.7459 - categorical_accuracy: 0.6964
# Epoch 19: saving model to model_init_exp_16_2024-04-2403_19_46.805264/model-00019-0.74589-0.69643-1.72534-0.21094.h5
# 21/21 [==============================] - 591s 28s/step - loss: 0.7459 - categorical_accuracy: 0.6964 - val_loss: 1.7253 - val_categorical_accuracy: 0.2109 - lr: 0.0010
# Epoch 20/38
# 21/21 [==============================] - ETA: 0s - loss: 0.6278 - categorical_accuracy: 0.7515
# Epoch 20: saving model to model_init_exp_16_2024-04-2403_19_46.805264/model-00020-0.62776-0.75149-1.84654-0.21094.h5
# 21/21 [==============================] - 591s 28s/step - loss: 0.6278 - categorical_accuracy: 0.7515 - val_loss: 1.8465 - val_categorical_accuracy: 0.2109 - lr: 0.0010
# Epoch 21/38
# 21/21 [==============================] - ETA: 0s - loss: 0.5992 - categorical_accuracy: 0.7500
# Epoch 21: saving model to model_init_exp_16_2024-04-2403_19_46.805264/model-00021-0.59917-0.75000-1.66459-0.24219.h5
# 21/21 [==============================] - 596s 28s/step - loss: 0.5992 - categorical_accuracy: 0.7500 - val_loss: 1.6646 - val_categorical_accuracy: 0.2422 - lr: 0.0010
# Epoch 22/38
# 21/21 [==============================] - ETA: 0s - loss: 0.5978 - categorical_accuracy: 0.7589
# Epoch 22: saving model to model_init_exp_16_2024-04-2403_19_46.805264/model-00022-0.59776-0.75893-1.63150-0.25781.h5
# 21/21 [==============================] - 591s 28s/step - loss: 0.5978 - categorical_accuracy: 0.7589 - val_loss: 1.6315 - val_categorical_accuracy: 0.2578 - lr: 0.0010
# Epoch 23/38
# 21/21 [==============================] - ETA: 0s - loss: 0.5584 - categorical_accuracy: 0.7634
# Epoch 23: saving model to model_init_exp_16_2024-04-2403_19_46.805264/model-00023-0.55840-0.76339-1.58180-0.29688.h5
# 21/21 [==============================] - 591s 28s/step - loss: 0.5584 - categorical_accuracy: 0.7634 - val_loss: 1.5818 - val_categorical_accuracy: 0.2969 - lr: 0.0010
# Epoch 24/38
# 21/21 [==============================] - ETA: 0s - loss: 0.5666 - categorical_accuracy: 0.7500
# Epoch 24: saving model to model_init_exp_16_2024-04-2403_19_46.805264/model-00024-0.56661-0.75000-1.34079-0.29688.h5
# 21/21 [==============================] - 590s 28s/step - loss: 0.5666 - categorical_accuracy: 0.7500 - val_loss: 1.3408 - val_categorical_accuracy: 0.2969 - lr: 0.0010
# Epoch 25/38
# 21/21 [==============================] - ETA: 0s - loss: 0.5335 - categorical_accuracy: 0.7708
# Epoch 25: saving model to model_init_exp_16_2024-04-2403_19_46.805264/model-00025-0.53352-0.77083-1.02309-0.35156.h5
# 21/21 [==============================] - 593s 28s/step - loss: 0.5335 - categorical_accuracy: 0.7708 - val_loss: 1.0231 - val_categorical_accuracy: 0.3516 - lr: 0.0010
# Epoch 26/38
# 21/21 [==============================] - ETA: 0s - loss: 0.5192 - categorical_accuracy: 0.7812
# Epoch 26: saving model to model_init_exp_16_2024-04-2403_19_46.805264/model-00026-0.51921-0.78125-0.87323-0.41406.h5
# 21/21 [==============================] - 599s 29s/step - loss: 0.5192 - categorical_accuracy: 0.7812 - val_loss: 0.8732 - val_categorical_accuracy: 0.4141 - lr: 0.0010
# Epoch 27/38
# 21/21 [==============================] - ETA: 0s - loss: 0.4814 - categorical_accuracy: 0.8021
# Epoch 27: saving model to model_init_exp_16_2024-04-2403_19_46.805264/model-00027-0.48142-0.80208-1.47945-0.34375.h5
# 21/21 [==============================] - 600s 29s/step - loss: 0.4814 - categorical_accuracy: 0.8021 - val_loss: 1.4795 - val_categorical_accuracy: 0.3438 - lr: 0.0010
# Epoch 28/38
# 21/21 [==============================] - ETA: 0s - loss: 0.5078 - categorical_accuracy: 0.7991
# Epoch 28: saving model to model_init_exp_16_2024-04-2403_19_46.805264/model-00028-0.50782-0.79911-0.78921-0.46875.h5
# 21/21 [==============================] - 598s 29s/step - loss: 0.5078 - categorical_accuracy: 0.7991 - val_loss: 0.7892 - val_categorical_accuracy: 0.4688 - lr: 0.0010
# Epoch 29/38
# 21/21 [==============================] - ETA: 0s - loss: 0.4758 - categorical_accuracy: 0.8080
# Epoch 29: saving model to model_init_exp_16_2024-04-2403_19_46.805264/model-00029-0.47580-0.80804-0.69742-0.74219.h5
# 21/21 [==============================] - 595s 28s/step - loss: 0.4758 - categorical_accuracy: 0.8080 - val_loss: 0.6974 - val_categorical_accuracy: 0.7422 - lr: 0.0010
# Epoch 30/38
# 21/21 [==============================] - ETA: 0s - loss: 0.5242 - categorical_accuracy: 0.7812
# Epoch 30: saving model to model_init_exp_16_2024-04-2403_19_46.805264/model-00030-0.52422-0.78125-0.91097-0.45312.h5
# 21/21 [==============================] - 590s 28s/step - loss: 0.5242 - categorical_accuracy: 0.7812 - val_loss: 0.9110 - val_categorical_accuracy: 0.4531 - lr: 0.0010
# Epoch 31/38
# 21/21 [==============================] - ETA: 0s - loss: 0.5001 - categorical_accuracy: 0.7961
# Epoch 31: saving model to model_init_exp_16_2024-04-2403_19_46.805264/model-00031-0.50013-0.79613-0.42972-0.62500.h5
# 21/21 [==============================] - 596s 28s/step - loss: 0.5001 - categorical_accuracy: 0.7961 - val_loss: 0.4297 - val_categorical_accuracy: 0.6250 - lr: 0.0010
# Epoch 32/38
# 21/21 [==============================] - ETA: 0s - loss: 0.5280 - categorical_accuracy: 0.7738
# Epoch 32: saving model to model_init_exp_16_2024-04-2403_19_46.805264/model-00032-0.52799-0.77381-0.55115-0.76562.h5
# 21/21 [==============================] - 602s 29s/step - loss: 0.5280 - categorical_accuracy: 0.7738 - val_loss: 0.5512 - val_categorical_accuracy: 0.7656 - lr: 0.0010
# Epoch 33/38
# 21/21 [==============================] - ETA: 0s - loss: 0.4557 - categorical_accuracy: 0.8065
# Epoch 33: saving model to model_init_exp_16_2024-04-2403_19_46.805264/model-00033-0.45565-0.80655-0.51134-0.55469.h5
# 21/21 [==============================] - 595s 28s/step - loss: 0.4557 - categorical_accuracy: 0.8065 - val_loss: 0.5113 - val_categorical_accuracy: 0.5547 - lr: 0.0010
# Epoch 34/38
# 21/21 [==============================] - ETA: 0s - loss: 0.4488 - categorical_accuracy: 0.8036
# Epoch 34: saving model to model_init_exp_16_2024-04-2403_19_46.805264/model-00034-0.44879-0.80357-0.54791-0.59375.h5
# 21/21 [==============================] - 600s 29s/step - loss: 0.4488 - categorical_accuracy: 0.8036 - val_loss: 0.5479 - val_categorical_accuracy: 0.5938 - lr: 0.0010
# Epoch 35/38
# 21/21 [==============================] - ETA: 0s - loss: 0.4437 - categorical_accuracy: 0.8185
# Epoch 35: saving model to model_init_exp_16_2024-04-2403_19_46.805264/model-00035-0.44374-0.81845-0.73058-0.50781.h5
# 21/21 [==============================] - 592s 28s/step - loss: 0.4437 - categorical_accuracy: 0.8185 - val_loss: 0.7306 - val_categorical_accuracy: 0.5078 - lr: 0.0010
# Epoch 36/38
# 21/21 [==============================] - ETA: 0s - loss: 0.4288 - categorical_accuracy: 0.8244
# Epoch 36: saving model to model_init_exp_16_2024-04-2403_19_46.805264/model-00036-0.42884-0.82440-0.44242-0.59375.h5
# 21/21 [==============================] - 595s 28s/step - loss: 0.4288 - categorical_accuracy: 0.8244 - val_loss: 0.4424 - val_categorical_accuracy: 0.5938 - lr: 0.0010
# Epoch 37/38
# 21/21 [==============================] - ETA: 0s - loss: 0.4267 - categorical_accuracy: 0.8571
# Epoch 37: saving model to model_init_exp_16_2024-04-2403_19_46.805264/model-00037-0.42671-0.85714-0.60469-0.56250.h5
# 21/21 [==============================] - 597s 29s/step - loss: 0.4267 - categorical_accuracy: 0.8571 - val_loss: 0.6047 - val_categorical_accuracy: 0.5625 - lr: 0.0010
# Epoch 38/38
# 21/21 [==============================] - ETA: 0s - loss: 0.4257 - categorical_accuracy: 0.8199
# Epoch 38: saving model to model_init_exp_16_2024-04-2403_19_46.805264/model-00038-0.42567-0.81994-0.45636-0.82812.h5
# 21/21 [==============================] - 592s 28s/step - loss: 0.4257 - categorical_accuracy: 0.8199 - val_loss: 0.4564 - val_categorical_accuracy: 0.8281 - lr: 0.0010

# %%
plt.figure(figsize=(20,6))
ax1 = plt.subplot(121)
ax1 = plt.plot(history.history['loss'])
ax1 = plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='lower left')
ax2 = plt.subplot(122)
ax2 = plt.plot(history.history['categorical_accuracy'])
ax2 = plt.plot(history.history['val_categorical_accuracy'])
plt.title('model accuracy')
plt.ylabel('categorical_accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='lower left')
